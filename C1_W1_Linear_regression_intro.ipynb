# %% [markdown]
# <a href="https://colab.research.google.com/github/vvithurshan/Machine-Learning/blob/main/C1_W1_Linear_regression_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([1, 2, 3, 4, 5])
y_train = np.array([200, 300, 400, 500 ,600])

# %%
plt.plot(x_train, y_train)
plt.scatter(x_train, y_train, c= 'r', marker = 'x')
plt.ylabel('Price (in 1000s of dollars)')
plt.xlabel('Area (1000 sq)')
plt.title('Housing Prices')
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def compute_model(x, w, b):
    m = x.shape[0]
    f_wb = np.zeros(m)

    for i in range(m):
        f_wb[i] = w * x[i] + b
        # print(f_wb)
    return f_wb
    # print(f_wb)

# %%
w = 100
b = 100
tem_f_wb = compute_model(x_train, w, b)

plt.plot(x_train, tem_f_wb, label = 'Prediction')
plt.scatter(x_train, y_train, c = 'r', label = 'Actual')
plt.ylabel('Price $')
plt.xlabel('Area sq')
plt.title('Housing Prices')
plt.legend()

# %%
prediction = 100 * 2.5 + 100
print(prediction)
# Out:
# 350.0

# %%
def compute_error(y_test, y_pred):
    error = np.mean(np.square(y_test - y_pred))
    return error

# %%
error = compute_error(y_train, tem_f_wb)
print(error)
# Out:
# 0.0

# %%
def compute_error_2(y_train, tem_f_wb):
    total = 0
    for i in range(len(y_train)):
        total += (y_train[i] - tem_f_wb[i])**2
    return total/len(y_train)

# %%
error = compute_error_2(y_train, tem_f_wb)
print(error)
# Out:
# 0.0
